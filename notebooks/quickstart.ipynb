# %% [markdown]
# # QuantBacktest 快速开始
#
# 该 Notebook 用于在 `backtest-system` 环境中检查输入规范、运行论文因子示例和阅读调试工件。

# %%
from pathlib import Path
import yaml
from quantbacktest import RunSpec, run_backtest

spec = RunSpec.model_validate(yaml.safe_load(Path('../examples/cross_sectional.yaml').read_text(encoding='utf-8')))
spec

# %%
# 从项目根目录执行时，将 project_root 改为 Path.cwd()。
# result = run_backtest(spec, Path('..').resolve())
# result.run_dir
